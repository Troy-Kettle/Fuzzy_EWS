# %%
import pandas as pd

# %%
from dataclasses import dataclass


@dataclass(frozen=True)
class Observation:
    hr: int
    bp: int
    temp: float
    resp: float
    ox_sats: float
    insp_ox: float

# %%
obs_1 = Observation(hr=52, bp=102, temp=36.2, resp=22, ox_sats=94, insp_ox=30)

# %% [markdown]
# <h1> Membership Functions

# %% [markdown]
# <h1> Fuzzy Variables

# %%
class custom_mf_7_var:
    """Input membership function for vitals with 7 categories (e.g., Heart Rate, BP, Temp, Resp)."""
    def __init__(self, path):
        self.path = path
        self.df = pd.read_csv(path)
        
        keys = self.df.loc[:, 'Value'].values
        
        self.B_SevC = dict(zip(keys, self.df.loc[:, 'Below normal - severe concern'].values))
        self.B_ModC = dict(zip(keys, self.df.loc[:, 'Below normal - moderate concern'].values))
        self.B_MildC = dict(zip(keys, self.df.loc[:, 'Below normal - mild concern'].values))
        self.no_con = dict(zip(keys, self.df.loc[:,'No concern'].values))
        self.A_MildC = dict(zip(keys, self.df.loc[:, 'Above normal - mild concern'].values))
        self.A_ModC = dict(zip(keys, self.df.loc[:, 'Above normal - moderate concern'].values))
        self.A_SevC = dict(zip(keys, self.df.loc[:, 'Above normal - severe concern'].values))
        
        self.fs = [self.B_SevC, self.B_ModC, self.B_MildC, self.no_con, self.A_MildC, self.A_ModC, self.A_SevC]
        self.labels = ['Below normal - severe concern', 'Below normal - moderate concern', 
                       'Below normal - mild concern', 'No concern', 
                       'Above normal - mild concern', 'Above normal - moderate concern', 
                       'Above normal - severe concern']
    
    def __call__(self, inp):
        out = {}
        for label, fs in zip(self.labels, self.fs):
            membership_value = fs.get(inp, 0.0)
            out[label] = membership_value
        
        return out
    
class custom_mf_3_var_up:
    """Input membership function for vitals with 3 upward categories (e.g., Inspired O2)."""
    def __init__(self, path):
        self.path = path
        self.df = pd.read_csv(path)
        
        keys = self.df.loc[:, 'Value'].values
        
        self.no_con = dict(zip(keys, self.df.loc[:,'No concern'].values))
        self.A_MildC = dict(zip(keys, self.df.loc[:, 'Above normal - mild concern'].values))
        self.A_ModC = dict(zip(keys, self.df.loc[:, 'Above normal - moderate concern'].values))
        self.A_SevC = dict(zip(keys, self.df.loc[:, 'Above normal - severe concern'].values))
        
        self.fs = [self.no_con, self.A_MildC, self.A_ModC, self.A_SevC]
        self.labels = ['No concern', 
                       'Above normal - mild concern', 'Above normal - moderate concern', 
                       'Above normal - severe concern']
    
    def __call__(self, inp):
        out = {}
        for label, fs in zip(self.labels, self.fs):
            membership_value = fs.get(inp, 0.0)
            out[label] = membership_value
        
        return out

        
class custom_mf_3_var_down:
    """Input membership function for vitals with 3 downward categories (e.g., O2 Saturation)."""
    def __init__(self, path):
        self.path = path
        self.df = pd.read_csv(path)
        
        keys = self.df.loc[:, 'Value'].values
        
        self.B_SevC = dict(zip(keys, self.df.loc[:, 'Below normal - severe concern'].values))
        self.B_ModC = dict(zip(keys, self.df.loc[:, 'Below normal - moderate concern'].values))
        self.B_MildC = dict(zip(keys, self.df.loc[:, 'Below normal - mild concern'].values))
        self.no_con = dict(zip(keys, self.df.loc[:,'No concern'].values))

        self.fs = [self.B_SevC, self.B_ModC, self.B_MildC, self.no_con]
        self.labels = ['Below normal - severe concern', 'Below normal - moderate concern', 
                       'Below normal - mild concern', 'No concern']
    
    def __call__(self, inp):
        out = {}
        for label, fs in zip(self.labels, self.fs):
            membership_value = fs.get(inp, 0.0)
            out[label] = membership_value
        
        return out

# %%
heart_rate = custom_mf_7_var('data/membership_function_plots/csv_data/heart_rate_membership_functions.csv')
blood_pressure = custom_mf_7_var('data/membership_function_plots/csv_data/systolic_blood_pressure_membership_functions.csv')
temperature = custom_mf_7_var('data/membership_function_plots/csv_data/temperature_membership_functions.csv')
respiratory_rate = custom_mf_7_var('data/membership_function_plots/csv_data/respiratory_rate_membership_functions.csv')
oxygen_saturation = custom_mf_3_var_down('data/membership_function_plots/csv_data/oxygen_saturation_membership_functions.csv')
inspired_oxygen = custom_mf_3_var_up('data/membership_function_plots/csv_data/inspired_oxygen_concentration_membership_functions.csv')



def firings(hr, bp, temp, resp, ox, insp):
    firings = {
        'heart rate' : heart_rate(hr),
        'blood_pressure' : blood_pressure(bp),
        'temp' : temperature(temp),
        'resp' : respiratory_rate(resp),
        'oxygen sats' : oxygen_saturation(ox),
        'inspired_oxygen' : inspired_oxygen(insp)
    }
    return firings
    
res = firings(obs_1.hr, obs_1.bp, obs_1.temp, obs_1.resp, obs_1.ox_sats, obs_1.insp_ox)
res
# Out:
# {'heart rate': {'Below normal - severe concern': np.float64(0.0),
#   'Below normal - moderate concern': np.float64(0.6),
#   'Below normal - mild concern': np.float64(0.4),
#   'No concern': np.float64(0.0),
#   'Above normal - mild concern': np.float64(0.0),
#   'Above normal - moderate concern': np.float64(0.0),
#   'Above normal - severe concern': np.float64(0.0)},
#  'blood_pressure': {'Below normal - severe concern': np.float64(0.0),
#   'Below normal - moderate concern': np.float64(0.0),
#   'Below normal - mild concern': np.float64(0.6),
#   'No concern': np.float64(1.0),
#   'Above normal - mild concern': np.float64(0.0),
#   'Above normal - moderate concern': np.float64(0.0),
#   'Above normal - severe concern': np.float64(0.0)},
#  'temp': {'Below normal - severe concern': np.float64(0.0),
#   'Below normal - moderate concern': np.float64(0.0),
#   'Below normal - mild concern': np.float64(1.0000000000000142),
#   'No concern': np.float64(0.0),
# ...

# %% [markdown]
# <h1> Inference Engine

# %%
# Inference Engine is now in the DeFuzz cell below
# This cell is kept for testing the firings output

# Test map to see what the firings look like
print("Testing firings for obs_1:")
for vital, memberships in res.items():
    print(f"\n{vital}:")
    for label, value in memberships.items():
        if value > 0:
            print(f"  {label}: {value:.2f}")
# Out:
# Testing firings for obs_1:
#
# heart rate:
#   Below normal - moderate concern: 0.60
#   Below normal - mild concern: 0.40
#
# blood_pressure:
#   Below normal - mild concern: 0.60
#   No concern: 1.00
#
# temp:
#   Below normal - mild concern: 1.00
#
# resp:
#   Above normal - mild concern: 1.00
#
# oxygen sats:
#   No concern: 1.00
#
# inspired_oxygen:
#   Above normal - moderate concern: 1.00

# %% [markdown]
# <h1> DeFuzz

# %%
class OutputMF:
    """
    Fuzzy output membership function for a SINGLE vital (0-3 scale).
    Uses overlapping trapezoids for proper fuzzy defuzzification.
    """
    def __init__(self):
        # Overlapping trapezoidal membership functions
        # Format: (a, b, c, d) where membership rises from a to b, 
        # is 1.0 from b to c, and falls from c to d
        self.definitions = {
            'No concern':       (-0.5, 0, 0, 0.75),      # Peak at 0
            'Mild concern':     (0.25, 1, 1, 1.75),      # Peak at 1
            'Moderate concern': (1.25, 2, 2, 2.75),      # Peak at 2
            'Severe concern':   (2.25, 3, 3, 3.5)        # Peak at 3
        }
    
    def trapezoid(self, x, a, b, c, d):
        """Calculate trapezoidal membership value."""
        if b <= x <= c:
            return 1.0
        elif x <= a or x >= d:
            return 0.0
        elif a < x < b:
            return (x - a) / (b - a)
        elif c < x < d:
            return (d - x) / (d - c)
        return 0.0
    
    def __call__(self, x):
        """Get membership values for all concern levels at point x."""
        results = {}
        for label, (a, b, c, d) in self.definitions.items():
            results[label] = self.trapezoid(x, a, b, c, d)
        return results

# Instantiate output MF
output = OutputMF()

# Pre-compute output membership values (0 to 3 in 0.01 steps for smooth centroid)
output_cache = {}
for i in range(0, 301):
    val = i / 100.0
    output_cache[val] = output(val)

def map_to_concern_levels(vital_memberships):
    """
    Maps input labels (e.g. "Below normal - severe concern") 
    to output labels ("Severe concern") for a single vital.
    Uses MAX to pick the strongest firing for each concern level.
    """
    mapping = {
        'No concern': 0.0,
        'Mild concern': 0.0,
        'Moderate concern': 0.0,
        'Severe concern': 0.0
    }
    
    for key, value in vital_memberships.items():
        key_lower = key.lower()
        if 'severe' in key_lower:
            mapping['Severe concern'] = max(mapping['Severe concern'], value)
        elif 'moderate' in key_lower:
            mapping['Moderate concern'] = max(mapping['Moderate concern'], value)
        elif 'mild' in key_lower:
            mapping['Mild concern'] = max(mapping['Mild concern'], value)
        elif 'no concern' in key_lower:
            mapping['No concern'] = max(mapping['No concern'], value)
    
    return mapping

def defuzz_vital_centroid(concern_levels):
    """
    Defuzzify using centroid method with fuzzy output MFs.
    This is proper fuzzy defuzzification using overlapping output membership functions.
    """
    numerator = 0.0
    denominator = 0.0
    
    for i in range(0, 301):  # 0.00 to 3.00 in 0.01 steps
        x = i / 100.0
        output_memberships = output_cache[x]
        
        # Aggregate using MAX of clipped (min) values - Mamdani inference
        aggregated = 0.0
        for level, firing in concern_levels.items():
            if firing > 0:
                membership = output_memberships.get(level, 0)
                clipped = min(firing, membership)  # Clip the output MF
                aggregated = max(aggregated, clipped)  # Aggregate with MAX
        
        numerator += x * aggregated
        denominator += aggregated
    
    if denominator == 0:
        return 0
    return numerator / denominator

def calculate_fuzzy_ews_additive(all_firings):
    """
    Calculate Fuzzy EWS using per-vital defuzzification + summation.
    Each vital gets a fuzzy score 0-3 via centroid defuzzification, then all are summed.
    Total range: 0-18 (6 vitals × 3 max each)
    """
    total_score = 0
    
    for vital_name, vital_memberships in all_firings.items():
        # Map input labels to output concern levels
        concern_levels = map_to_concern_levels(vital_memberships)
        
        # Defuzzify this vital (0-3) using centroid method
        vital_score = defuzz_vital_centroid(concern_levels)
        
        # Sum it
        total_score += vital_score
    
    return total_score

# Test with example
print("Per-vital defuzzification system ready (Centroid method with fuzzy output MFs)!")
print("\nTest with obs_1:")
test_firings = firings(obs_1.hr, obs_1.bp, obs_1.temp, obs_1.resp, obs_1.ox_sats, obs_1.insp_ox)
print("\nPer-vital scores:")
for vital_name, vital_memberships in test_firings.items():
    concern = map_to_concern_levels(vital_memberships)
    score = defuzz_vital_centroid(concern)
    print(f"  {vital_name}: {score:.2f} (concern levels: {concern})")
total = calculate_fuzzy_ews_additive(test_firings)
print(f"\nTotal Fuzzy EWS: {total:.2f}")

# Diagnostic: Test with edge cases
print("\n" + "="*60)
print("DIAGNOSTIC: Testing edge cases")
print("="*60)

# Test: What does a "No concern" firing of 1.0 defuzzify to?
test_no_concern = {'No concern': 1.0, 'Mild concern': 0.0, 'Moderate concern': 0.0, 'Severe concern': 0.0}
print(f"\nPure 'No concern' (1.0) → defuzz = {defuzz_vital_centroid(test_no_concern):.3f}")

test_mild = {'No concern': 0.0, 'Mild concern': 1.0, 'Moderate concern': 0.0, 'Severe concern': 0.0}
print(f"Pure 'Mild concern' (1.0) → defuzz = {defuzz_vital_centroid(test_mild):.3f}")

test_moderate = {'No concern': 0.0, 'Mild concern': 0.0, 'Moderate concern': 1.0, 'Severe concern': 0.0}
print(f"Pure 'Moderate concern' (1.0) → defuzz = {defuzz_vital_centroid(test_moderate):.3f}")

test_severe = {'No concern': 0.0, 'Mild concern': 0.0, 'Moderate concern': 0.0, 'Severe concern': 1.0}
print(f"Pure 'Severe concern' (1.0) → defuzz = {defuzz_vital_centroid(test_severe):.3f}")

# Test: Mixed firings (fuzzy behavior)
test_mixed = {'No concern': 0.5, 'Mild concern': 0.5, 'Moderate concern': 0.0, 'Severe concern': 0.0}
print(f"\nMixed: No concern=0.5, Mild=0.5 → defuzz = {defuzz_vital_centroid(test_mixed):.3f}")

test_mixed2 = {'No concern': 0.0, 'Mild concern': 0.3, 'Moderate concern': 0.7, 'Severe concern': 0.0}
print(f"Mixed: Mild=0.3, Moderate=0.7 → defuzz = {defuzz_vital_centroid(test_mixed2):.3f}")
# Out:
# Per-vital defuzzification system ready (Weighted Average method)!
#
# Test with obs_1:
#
# Per-vital scores:
#   heart rate: 1.60 (concern levels: {'No concern': 0.0, 'Mild concern': np.float64(0.4), 'Moderate concern': np.float64(0.6), 'Severe concern': 0.0})
#   blood_pressure: 0.37 (concern levels: {'No concern': np.float64(1.0), 'Mild concern': np.float64(0.6), 'Moderate concern': 0.0, 'Severe concern': 0.0})
#   temp: 1.00 (concern levels: {'No concern': 0.0, 'Mild concern': np.float64(1.0000000000000142), 'Moderate concern': 0.0, 'Severe concern': 0.0})
#   resp: 1.00 (concern levels: {'No concern': 0.0, 'Mild concern': np.float64(1.0), 'Moderate concern': 0.0, 'Severe concern': 0.0})
#   oxygen sats: 0.00 (concern levels: {'No concern': np.float64(1.0), 'Mild concern': 0.0, 'Moderate concern': 0.0, 'Severe concern': 0.0})
#   inspired_oxygen: 2.00 (concern levels: {'No concern': 0.0, 'Mild concern': 0.0, 'Moderate concern': np.float64(1.0), 'Severe concern': 0.0})
#
# ...

# %%
# ============================================
# Membership Function Visualization
# ============================================

import matplotlib.pyplot as plt
import numpy as np

# Load all membership function data
hr_df = pd.read_csv('data/membership_function_plots/csv_data/heart_rate_membership_functions.csv')
bp_df = pd.read_csv('data/membership_function_plots/csv_data/systolic_blood_pressure_membership_functions.csv')
temp_df = pd.read_csv('data/membership_function_plots/csv_data/temperature_membership_functions.csv')
resp_df = pd.read_csv('data/membership_function_plots/csv_data/respiratory_rate_membership_functions.csv')
ox_df = pd.read_csv('data/membership_function_plots/csv_data/oxygen_saturation_membership_functions.csv')
insp_df = pd.read_csv('data/membership_function_plots/csv_data/inspired_oxygen_concentration_membership_functions.csv')

# Color scheme for membership functions
colors_7 = {
    'Below normal - severe concern': '#d62728',
    'Below normal - moderate concern': '#ff7f0e',
    'Below normal - mild concern': '#ffbb78',
    'No concern': '#2ca02c',
    'Above normal - mild concern': '#aec7e8',
    'Above normal - moderate concern': '#1f77b4',
    'Above normal - severe concern': '#9467bd'
}

colors_down = {
    'Below normal - severe concern': '#d62728',
    'Below normal - moderate concern': '#ff7f0e',
    'Below normal - mild concern': '#ffbb78',
    'No concern': '#2ca02c'
}

colors_up = {
    'No concern': '#2ca02c',
    'Above normal - mild concern': '#aec7e8',
    'Above normal - moderate concern': '#1f77b4',
    'Above normal - severe concern': '#9467bd'
}

# Create figure with subplots
fig, axes = plt.subplots(3, 2, figsize=(16, 14))
fig.suptitle('Input Membership Functions for Fuzzy EWS', fontsize=18, fontweight='bold')

# --- Plot 1: Heart Rate ---
ax1 = axes[0, 0]
x_hr = hr_df['Value'].values
for col in hr_df.columns[1:]:
    ax1.plot(x_hr, hr_df[col].values, label=col, color=colors_7.get(col, 'gray'), linewidth=2, alpha=0.8)
    ax1.fill_between(x_hr, hr_df[col].values, alpha=0.1, color=colors_7.get(col, 'gray'))
ax1.set_xlabel('Heart Rate (bpm)', fontsize=11)
ax1.set_ylabel('Membership Degree', fontsize=11)
ax1.set_title('Heart Rate Membership Functions', fontsize=12, fontweight='bold')
ax1.set_ylim(0, 1.05)
ax1.grid(True, alpha=0.3)
ax1.legend(loc='upper right', fontsize=7)

# --- Plot 2: Blood Pressure ---
ax2 = axes[0, 1]
x_bp = bp_df['Value'].values
for col in bp_df.columns[1:]:
    ax2.plot(x_bp, bp_df[col].values, label=col, color=colors_7.get(col, 'gray'), linewidth=2, alpha=0.8)
    ax2.fill_between(x_bp, bp_df[col].values, alpha=0.1, color=colors_7.get(col, 'gray'))
ax2.set_xlabel('Systolic Blood Pressure (mmHg)', fontsize=11)
ax2.set_ylabel('Membership Degree', fontsize=11)
ax2.set_title('Systolic Blood Pressure Membership Functions', fontsize=12, fontweight='bold')
ax2.set_ylim(0, 1.05)
ax2.grid(True, alpha=0.3)
ax2.legend(loc='upper right', fontsize=7)

# --- Plot 3: Temperature ---
ax3 = axes[1, 0]
x_temp = temp_df['Value'].values
for col in temp_df.columns[1:]:
    ax3.plot(x_temp, temp_df[col].values, label=col, color=colors_7.get(col, 'gray'), linewidth=2, alpha=0.8)
    ax3.fill_between(x_temp, temp_df[col].values, alpha=0.1, color=colors_7.get(col, 'gray'))
ax3.set_xlabel('Temperature (°C)', fontsize=11)
ax3.set_ylabel('Membership Degree', fontsize=11)
ax3.set_title('Temperature Membership Functions', fontsize=12, fontweight='bold')
ax3.set_ylim(0, 1.05)
ax3.grid(True, alpha=0.3)
ax3.legend(loc='upper right', fontsize=7)

# --- Plot 4: Respiratory Rate ---
ax4 = axes[1, 1]
x_resp = resp_df['Value'].values
for col in resp_df.columns[1:]:
    ax4.plot(x_resp, resp_df[col].values, label=col, color=colors_7.get(col, 'gray'), linewidth=2, alpha=0.8)
    ax4.fill_between(x_resp, resp_df[col].values, alpha=0.1, color=colors_7.get(col, 'gray'))
ax4.set_xlabel('Respiratory Rate (breaths/min)', fontsize=11)
ax4.set_ylabel('Membership Degree', fontsize=11)
ax4.set_title('Respiratory Rate Membership Functions', fontsize=12, fontweight='bold')
ax4.set_ylim(0, 1.05)
ax4.grid(True, alpha=0.3)
ax4.legend(loc='upper right', fontsize=7)

# --- Plot 5: Oxygen Saturation ---
ax5 = axes[2, 0]
x_ox = ox_df['Value'].values
for col in ox_df.columns[1:]:
    ax5.plot(x_ox, ox_df[col].values, label=col, color=colors_down.get(col, 'gray'), linewidth=2, alpha=0.8)
    ax5.fill_between(x_ox, ox_df[col].values, alpha=0.1, color=colors_down.get(col, 'gray'))
ax5.set_xlabel('Oxygen Saturation (%)', fontsize=11)
ax5.set_ylabel('Membership Degree', fontsize=11)
ax5.set_title('Oxygen Saturation Membership Functions', fontsize=12, fontweight='bold')
ax5.set_ylim(0, 1.05)
ax5.grid(True, alpha=0.3)
ax5.legend(loc='upper left', fontsize=8)

# --- Plot 6: Inspired Oxygen ---
ax6 = axes[2, 1]
x_insp = insp_df['Value'].values
for col in insp_df.columns[1:]:
    ax6.plot(x_insp, insp_df[col].values, label=col, color=colors_up.get(col, 'gray'), linewidth=2, alpha=0.8)
    ax6.fill_between(x_insp, insp_df[col].values, alpha=0.1, color=colors_up.get(col, 'gray'))
ax6.set_xlabel('Inspired Oxygen Concentration (%)', fontsize=11)
ax6.set_ylabel('Membership Degree', fontsize=11)
ax6.set_title('Inspired Oxygen Membership Functions', fontsize=12, fontweight='bold')
ax6.set_ylim(0, 1.05)
ax6.grid(True, alpha=0.3)
ax6.legend(loc='upper left', fontsize=8)

plt.tight_layout()
plt.subplots_adjust(top=0.94)
plt.show()

# --- Fuzzy Output Membership Function (0-3 per vital) ---
fig2, ax_out = plt.subplots(figsize=(12, 5))
fig2.suptitle('Fuzzy Output Membership Functions (Per-Vital Score 0-3)', fontsize=14, fontweight='bold')

output_colors = {
    'No concern': '#2ca02c',
    'Mild concern': '#ffbb78',
    'Moderate concern': '#ff7f0e',
    'Severe concern': '#d62728'
}

x_out = np.linspace(0, 3, 300)

for label, (a, b, c, d) in output.definitions.items():
    y_out = [output.trapezoid(x, a, b, c, d) for x in x_out]
    ax_out.plot(x_out, y_out, label=label, color=output_colors.get(label, 'gray'), linewidth=3, alpha=0.8)
    ax_out.fill_between(x_out, y_out, alpha=0.15, color=output_colors.get(label, 'gray'))

ax_out.set_xlabel('Per-Vital Score (Defuzzified via Centroid)', fontsize=12)
ax_out.set_ylabel('Membership Degree', fontsize=12)
ax_out.set_title('Overlapping Fuzzy Output MFs → Centroid Defuzzification → Sum 6 vitals → Total 0-18', fontsize=11)
ax_out.set_xlim(0, 3)
ax_out.set_ylim(0, 1.05)
ax_out.set_xticks([0, 1, 2, 3])
ax_out.set_xticklabels(['0\n(None)', '1\n(Mild)', '2\n(Moderate)', '3\n(Severe)'])
ax_out.grid(True, alpha=0.3)
ax_out.legend(loc='upper right', fontsize=10)

plt.tight_layout()
plt.show()

print("✓ All membership functions visualized successfully!")
# Out:
# ✓ All membership functions visualized successfully!

# %%
# ============================================
# Process Real Dataset and Add Fuzzy EWS Score
# ============================================
from tqdm import tqdm

# Load the Excel file
input_file = 'Annotated dataset_training_anonymised_V5_Troy.xlsx'
df_real = pd.read_excel(input_file)

print(f"Loaded {len(df_real)} rows from dataset")

# Function to calculate Fuzzy EWS for a single row
def calculate_fuzzy_ews(row):
    try:
        # Get raw values
        hr = int(row['HEART_RATE'])
        bp = int(row['SYSTOLIC_BP'])
        temp = float(row['TEMPERATURE'])
        resp = int(row['RESP_RATE'])
        ox_sats = int(row['O2_SATS'])
        
        # CLAMP values to membership function ranges
        hr = max(30, min(142, hr))
        bp = max(70, min(192, bp))
        temp = round(max(34.0, min(41.2, temp)), 1)
        resp = max(6, min(32, resp))
        ox_sats = max(80, min(102, ox_sats))
        
        # Handle INSPIRED_O2 - data appears to be in FiO2% already!
        # Values like 21, 28, 35, 40, 60 are percentages
        # Small values (0.5, 1, 2, 3, 4, 5) are likely litres/min
        insp_o2_raw = row['INSPIRED_O2']
        if pd.isna(insp_o2_raw) or insp_o2_raw == 0:
            insp_ox = 21  # Room air
        elif insp_o2_raw <= 15:
            # Likely litres/min - convert to FiO2%
            # Rough conversion: FiO2 ≈ 21 + (4 × L/min)
            insp_ox = int(21 + (insp_o2_raw * 4))
        else:
            # Already in FiO2%
            insp_ox = int(insp_o2_raw)
        insp_ox = max(21, min(102, insp_ox))
        
        # 1. Fuzzification: Get firings for all vitals
        all_firings = firings(hr, bp, temp, resp, ox_sats, insp_ox)
        
        # 2. Per-vital defuzzification + summation
        fuzzy_score = calculate_fuzzy_ews_additive(all_firings)
        
        return round(fuzzy_score, 2)
    except:
        return None

# Apply with progress bar
print("Calculating Fuzzy EWS scores (per-vital 0-3, summed)...")
fuzzy_scores = []
for idx, row in tqdm(df_real.iterrows(), total=len(df_real)):
    fuzzy_scores.append(calculate_fuzzy_ews(row))

df_real['FUZZY_EWS_SCORE'] = fuzzy_scores

# Count successful calculations
valid_scores = df_real['FUZZY_EWS_SCORE'].notna().sum()
print(f"✓ Calculated {valid_scores}/{len(df_real)} Fuzzy EWS scores")

# Save to new Excel file
output_file = 'Annotated_dataset_with_Fuzzy_EWS.xlsx'
df_real.to_excel(output_file, index=False)
print(f"✓ Saved to: {output_file}")

# Show comparison
print("\nSample comparison: NEWS-2 vs Fuzzy EWS")
comparison_cols = ['HEART_RATE', 'SYSTOLIC_BP', 'TEMPERATURE', 'RESP_RATE', 'O2_SATS', 'INSPIRED_O2', 'NEWS_2_SCORE', 'FUZZY_EWS_SCORE']
df_real[comparison_cols].head(20)
# Out:
# Loaded 55271 rows from dataset
# Calculating Fuzzy EWS scores (per-vital 0-3, summed)...
# 100%|██████████| 55271/55271 [00:01<00:00, 28268.79it/s]
# ✓ Calculated 54599/55271 Fuzzy EWS scores
# ✓ Saved to: Annotated_dataset_with_Fuzzy_EWS.xlsx
#
# Sample comparison: NEWS-2 vs Fuzzy EWS
# ✓ Saved to: Annotated_dataset_with_Fuzzy_EWS.xlsx
#
# Sample comparison: NEWS-2 vs Fuzzy EWS
#     HEART_RATE  SYSTOLIC_BP  TEMPERATURE  RESP_RATE  O2_SATS  INSPIRED_O2  \
# 0         98.0        121.0         36.6       19.0     97.0          2.0
# 1         90.0        123.0         36.2       20.0     96.0          2.0
# 2        109.0        119.0         36.5       19.0     98.0          2.0
# 3        106.0        122.0         36.4       19.0     97.0          2.0
# 4         95.0        120.0         36.6       18.0     96.0          2.0
# 5         92.0        102.0         36.1       19.0     94.0          2.0
# 6        100.0        126.0         36.2       18.0     94.0          2.0
# ...

# %%
# ============================================
# Visualizations: Fuzzy EWS vs NEWS-2 (Real Data)
# ============================================

import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# Filter out rows with missing scores
df_valid = df_real.dropna(subset=['FUZZY_EWS_SCORE', 'NEWS_2_SCORE'])
fuzzy_scores = df_valid['FUZZY_EWS_SCORE'].values
news2_scores = df_valid['NEWS_2_SCORE'].values

print(f"Analyzing {len(df_valid)} valid observations")

# Create figure with subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Fuzzy EWS vs NEWS-2 Comparison (Real Patient Data)', fontsize=16, fontweight='bold')

# --- Plot 1: Scatter Plot with Correlation ---
ax1 = axes[0, 0]
ax1.scatter(news2_scores, fuzzy_scores, alpha=0.3, s=20, c='steelblue', edgecolors='none')

# Add trend line
z = np.polyfit(news2_scores, fuzzy_scores, 1)
p = np.poly1d(z)
x_line = np.linspace(news2_scores.min(), news2_scores.max(), 100)
ax1.plot(x_line, p(x_line), "r--", linewidth=2, label=f'Trend: y={z[0]:.2f}x+{z[1]:.2f}')

# Calculate correlation
correlation, p_value = stats.pearsonr(news2_scores, fuzzy_scores)
ax1.text(0.05, 0.95, f'r = {correlation:.3f}\np < 0.001', transform=ax1.transAxes, fontsize=11, 
         verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

ax1.set_xlabel('NEWS-2 Score', fontsize=11)
ax1.set_ylabel('Fuzzy EWS Score', fontsize=11)
ax1.set_title('Correlation: Fuzzy EWS vs NEWS-2', fontsize=12)
ax1.legend(loc='lower right')
ax1.grid(True, alpha=0.3)

# --- Plot 2: Distribution Comparison (Histograms) ---
ax2 = axes[0, 1]
ax2.hist(news2_scores, bins=range(0, 21), alpha=0.6, label='NEWS-2', color='indianred', edgecolor='black')
ax2.hist(fuzzy_scores, bins=np.arange(0, 21, 1), alpha=0.6, label='Fuzzy EWS', color='steelblue', edgecolor='black')
ax2.set_xlabel('Score', fontsize=11)
ax2.set_ylabel('Frequency', fontsize=11)
ax2.set_title('Score Distribution Comparison', fontsize=12)
ax2.legend()
ax2.grid(True, alpha=0.3, axis='y')

# --- Plot 3: Box Plot Comparison ---
ax3 = axes[0, 2]
box_data = [news2_scores, fuzzy_scores]
bp = ax3.boxplot(box_data, labels=['NEWS-2', 'Fuzzy EWS'], patch_artist=True)
bp['boxes'][0].set_facecolor('indianred')
bp['boxes'][1].set_facecolor('steelblue')
ax3.set_ylabel('Score', fontsize=11)
ax3.set_title('Score Distribution (Box Plot)', fontsize=12)
ax3.grid(True, alpha=0.3, axis='y')

# Add stats
ax3.text(0.7, 0.95, f'NEWS-2:\n  Mean: {news2_scores.mean():.1f}\n  Median: {np.median(news2_scores):.1f}', 
         transform=ax3.transAxes, fontsize=9, verticalalignment='top')
ax3.text(0.7, 0.70, f'Fuzzy:\n  Mean: {fuzzy_scores.mean():.1f}\n  Median: {np.median(fuzzy_scores):.1f}', 
         transform=ax3.transAxes, fontsize=9, verticalalignment='top')

# --- Plot 4: Fuzzy EWS by NEWS-2 Category ---
ax4 = axes[1, 0]

# Categorize NEWS-2 scores
def news2_category(score):
    if score <= 4:
        return 'Low (0-4)'
    elif score <= 6:
        return 'Medium (5-6)'
    else:
        return 'High (7+)'

df_valid['NEWS2_Category'] = df_valid['NEWS_2_SCORE'].apply(news2_category)
categories = ['Low (0-4)', 'Medium (5-6)', 'High (7+)']
cat_data = [df_valid[df_valid['NEWS2_Category'] == cat]['FUZZY_EWS_SCORE'].values for cat in categories]

bp2 = ax4.boxplot(cat_data, labels=categories, patch_artist=True)
colors_cat = ['#2ca02c', '#ff7f0e', '#d62728']
for patch, color in zip(bp2['boxes'], colors_cat):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)

ax4.set_xlabel('NEWS-2 Risk Category', fontsize=11)
ax4.set_ylabel('Fuzzy EWS Score', fontsize=11)
ax4.set_title('Fuzzy EWS Distribution by NEWS-2 Category', fontsize=12)
ax4.grid(True, alpha=0.3, axis='y')

# --- Plot 5: Heatmap (2D Histogram) ---
ax5 = axes[1, 1]
h = ax5.hist2d(news2_scores, fuzzy_scores, bins=[range(0, 21), np.arange(0, 15, 0.5)], cmap='Blues')
plt.colorbar(h[3], ax=ax5, label='Count')
ax5.set_xlabel('NEWS-2 Score', fontsize=11)
ax5.set_ylabel('Fuzzy EWS Score', fontsize=11)
ax5.set_title('Score Density Heatmap', fontsize=12)

# --- Plot 6: Mean Fuzzy Score per NEWS-2 Score ---
ax6 = axes[1, 2]
news2_unique = sorted(df_valid['NEWS_2_SCORE'].unique())
mean_fuzzy = [df_valid[df_valid['NEWS_2_SCORE'] == n]['FUZZY_EWS_SCORE'].mean() for n in news2_unique]
std_fuzzy = [df_valid[df_valid['NEWS_2_SCORE'] == n]['FUZZY_EWS_SCORE'].std() for n in news2_unique]

ax6.bar(news2_unique, mean_fuzzy, yerr=std_fuzzy, capsize=3, color='steelblue', alpha=0.7, edgecolor='black')
ax6.set_xlabel('NEWS-2 Score', fontsize=11)
ax6.set_ylabel('Mean Fuzzy EWS Score', fontsize=11)
ax6.set_title('Mean Fuzzy EWS by NEWS-2 Score', fontsize=12)
ax6.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.subplots_adjust(top=0.93)
plt.show()

# Print summary statistics
print("\n" + "="*70)
print("SUMMARY STATISTICS")
print("="*70)
print(f"\nCorrelation (Pearson r): {correlation:.4f}")
print(f"P-value: {p_value:.2e}")
print(f"\nNEWS-2 Scores:")
print(f"  Mean: {news2_scores.mean():.2f}, Std: {news2_scores.std():.2f}")
print(f"  Min: {news2_scores.min()}, Max: {news2_scores.max()}")
print(f"\nFuzzy EWS Scores:")
print(f"  Mean: {fuzzy_scores.mean():.2f}, Std: {fuzzy_scores.std():.2f}")
print(f"  Min: {fuzzy_scores.min():.2f}, Max: {fuzzy_scores.max():.2f}")
# Out:
# Analyzing 54454 valid observations
# /var/folders/lr/qr2mnxdx52scw13y4vwbcwdm0000gn/T/ipykernel_99210/1554509331.py:54: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax3.boxplot(box_data, labels=['NEWS-2', 'Fuzzy EWS'], patch_artist=True)
# /var/folders/lr/qr2mnxdx52scw13y4vwbcwdm0000gn/T/ipykernel_99210/1554509331.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_valid['NEWS2_Category'] = df_valid['NEWS_2_SCORE'].apply(news2_category)
# ...

# %%
# ============================================
# Diagnostic: Check where disagreements occur
# ============================================

# Find cases where NEWS-2 and Fuzzy EWS disagree significantly
df_valid_copy = df_valid.copy()
df_valid_copy['Score_Diff'] = df_valid_copy['FUZZY_EWS_SCORE'] - df_valid_copy['NEWS_2_SCORE']

print("Cases with largest discrepancies (Fuzzy - NEWS-2):")
print("\n--- Fuzzy MUCH HIGHER than NEWS-2 (diff > 3) ---")
high_diff = df_valid_copy[df_valid_copy['Score_Diff'] > 3].head(5)
for idx, row in high_diff.iterrows():
    print(f"\nNEWS-2: {row['NEWS_2_SCORE']:.0f}, Fuzzy: {row['FUZZY_EWS_SCORE']:.2f}, Diff: {row['Score_Diff']:.2f}")
    print(f"  HR={row['HEART_RATE']}, BP={row['SYSTOLIC_BP']}, Temp={row['TEMPERATURE']}, Resp={row['RESP_RATE']}, O2={row['O2_SATS']}, InspO2={row['INSPIRED_O2']}")
    
    # Calculate per-vital breakdown
    hr = int(max(30, min(142, row['HEART_RATE'])))
    bp = int(max(70, min(192, row['SYSTOLIC_BP'])))
    temp = round(max(34.0, min(41.2, float(row['TEMPERATURE']))), 1)
    resp = int(max(6, min(32, row['RESP_RATE'])))
    ox = int(max(80, min(102, row['O2_SATS'])))
    insp = 21 if pd.isna(row['INSPIRED_O2']) or row['INSPIRED_O2'] == 0 else min(21 + int(row['INSPIRED_O2']) * 4, 100)
    insp = max(21, min(102, insp))
    
    all_f = firings(hr, bp, temp, resp, ox, insp)
    print(f"  Per-vital scores:")
    for vname, vmem in all_f.items():
        concern = map_to_concern_levels(vmem)
        score = defuzz_vital_weighted(concern)
        active_concerns = {k: v for k, v in concern.items() if v > 0}
        print(f"    {vname}: {score:.2f} {active_concerns}")

print("\n--- Fuzzy MUCH LOWER than NEWS-2 (diff < -3) ---")
low_diff = df_valid_copy[df_valid_copy['Score_Diff'] < -3].head(5)
for idx, row in low_diff.iterrows():
    print(f"\nNEWS-2: {row['NEWS_2_SCORE']:.0f}, Fuzzy: {row['FUZZY_EWS_SCORE']:.2f}, Diff: {row['Score_Diff']:.2f}")
    print(f"  HR={row['HEART_RATE']}, BP={row['SYSTOLIC_BP']}, Temp={row['TEMPERATURE']}, Resp={row['RESP_RATE']}, O2={row['O2_SATS']}, InspO2={row['INSPIRED_O2']}")

# Check what a perfectly normal observation gives
print("\n" + "="*60)
print("DIAGNOSTIC: Perfectly normal vitals")
print("="*60)
# NEWS-2 normal ranges: HR 51-90, BP 111-219, Temp 36.1-38.0, Resp 12-20, O2 ≥96%, Air
normal_f = firings(75, 120, 37.0, 16, 98, 21)
print("\nNormal vitals: HR=75, BP=120, Temp=37.0, Resp=16, O2=98%, Room air")
total_normal = 0
for vname, vmem in normal_f.items():
    concern = map_to_concern_levels(vmem)
    score = defuzz_vital_weighted(concern)
    total_normal += score
    print(f"  {vname}: {score:.2f} (concern: {concern})")
print(f"\nTotal Fuzzy EWS for normal: {total_normal:.2f} (should be 0)")
# Out:
# Cases with largest discrepancies (Fuzzy - NEWS-2):
#
# --- Fuzzy MUCH HIGHER than NEWS-2 (diff > 3) ---
#
# NEWS-2: 2, Fuzzy: 5.50, Diff: 3.50
#   HR=86.0, BP=169.0, Temp=36.1, Resp=19.0, O2=96.0, InspO2=1.0
#   Per-vital scores:
#     heart rate: 0.00 {'No concern': np.float64(1.0)}
#     blood_pressure: 3.00 {'Severe concern': np.float64(1.0)}
#     temp: 1.50 {'Mild concern': np.float64(0.5000000000000071), 'Moderate concern': np.float64(0.5000000000000071)}
#     resp: 0.00 {'No concern': np.float64(1.0)}
#     oxygen sats: 0.00 {'No concern': np.float64(1.0)}
#     inspired_oxygen: 1.00 {'Mild concern': np.float64(1.0)}
#
# NEWS-2: 4, Fuzzy: 8.00, Diff: 4.00
#   HR=118.0, BP=182.0, Temp=36.2, Resp=18.0, O2=92.0, InspO2=21.0
#   Per-vital scores:
#     heart rate: 3.00 {'Severe concern': np.float64(1.0)}
#     blood_pressure: 3.00 {'Severe concern': np.float64(1.0)}
#     temp: 1.00 {'Mild concern': np.float64(1.0000000000000142)}
#     resp: 0.00 {'No concern': np.float64(1.0)}
# ...

# %%
# Check the INSPIRED_O2 field values
print("INSPIRED_O2 value distribution:")
print(df_real['INSPIRED_O2'].value_counts().head(20))

print("\n\nChecking what inspired_oxygen MF does with different inputs:")
print(f"  inspired_oxygen(21) = {inspired_oxygen(21)}")  # Room air
print(f"  inspired_oxygen(25) = {inspired_oxygen(25)}")  # 25%
print(f"  inspired_oxygen(40) = {inspired_oxygen(40)}")  # 40%

# Check what NEWS-2 says about inspired O2
# NEWS-2: Score 2 if on supplemental O2 (any amount)
print("\n\nNEWS-2 Inspired O2 scoring:")
print("  Room air (21%) = 0")
print("  ANY supplemental O2 = 2")

# So if INSPIRED_O2 in your data represents LITRES (e.g., 1, 2, 3 L/min)
# Then 0 or NaN = room air = 0 points
# Any value > 0 = supplemental O2 = 2 points in NEWS-2

# Your current code converts litres to FiO2%: 21 + (litres * 4)
# So 1 L/min = 25%, 2 L/min = 29%, etc.

# But your MF has categories going up to "severe concern" which doesn't exist in NEWS-2!
# Out:
# INSPIRED_O2 value distribution:
# INSPIRED_O2
# 21.0    21140
# 2.0      8798
# 1.0      6400
# 4.0      4401
# 3.0      3158
# 28.0     2309
# 35.0     1742
# 40.0     1199
# 60.0      845
# 5.0       701
# 15.0      457
# 0.5       366
# 24.0      312
# 8.0       276
# 10.0      265
# 6.0       236
# 50.0      229
# 30.0      211
# 80.0      134
# 45.0      129
# Name: count, dtype: int64
#
#
# Checking what inspired_oxygen MF does with different inputs:
#   inspired_oxygen(21) = {'No concern': np.float64(1.0), 'Above normal - mild concern': np.float64(0.0), 'Above normal - moderate concern': np.float64(0.0), 'Above normal - severe concern': np.float64(0.0)}
#   inspired_oxygen(25) = {'No concern': np.float64(0.0), 'Above normal - mild concern': np.float64(1.0), 'Above normal - moderate concern': np.float64(0.0), 'Above normal - severe concern': np.float64(0.0)}
# ...
