# %%
import pandas as pd

# %%
from dataclasses import dataclass


@dataclass(frozen=True)
class Observation:
    hr: int
    bp: int
    temp: float
    resp: float
    ox_sats: float
    insp_ox: float

# %%
obs_1 = Observation(hr=70, bp=115, temp=37, resp=36.6, ox_sats=98, insp_ox=0)

# %% [markdown]
# <h1> Membership Functions

# %%
# take in an input int -> determine how much it belongs to the mf -> output that value

class tri_mf:
    def __init__(self, x, a, b, c):
        self.x = x
        self.a = a
        self.b = b
        self.c = c
        
    def __repr__(self):
        return f'Lower_Bound = {self.a}, Centre = {self.b}, Upper_Bound = {self.c}'

    def __call__(self, x, a, b, c):
        if x <= a or x >= c:
            return 0
        elif x > a and x < b:
            return (x - a) / (b - a)
        elif x == b:
            return 1.0
        elif x > b and x < c:
            return (c - x) / (c - b)
        
        
class trap_mf:
    def __init__(self, a, b, c, d):
        self.a = a
        self.b = b
        self.c = c
        self.d = d
        
    def __repr__(self):
        return f'Lower_bound: {self.a}, Centre_point_1: {self.b}, Centre_point_2: {self.c}, Upper_bound: {self.d}'
    
    def __call__(self, x):
        if x <= self.a or x >=self.d:
            return 0.0
        elif x > self.a and x < self.b:
            return (x - self.a) / (self.b - self.a)
        elif x > self.b and x < self.c or x == self.b or self.c:
            return 1.0
        elif x > self.c and x < self.d:
            return (self.d - x) / (self.d - self.c)

# %% [markdown]
# <h1> Fuzzy Variables

# %%
class FuzzyVariable:
    def __init__(self, name, mfs: dict):
        self.name = name
        self.mfs = mfs
        
    def fuzzyify(self, x):
        return {label: mf(x) for label, mf in self.mfs.items()}

# %%
heart_rate = FuzzyVariable(
    name = "Heart Rate",
    mfs ={
    "Low": trap_mf(0, 40, 50, 60),
    "Normal" : trap_mf(50,60,80,100),
    "High" : trap_mf(90,110,130,160),
    "Very High": trap_mf(120,140,200,220)
    })

print(heart_rate.fuzzyify(110))
# Out:
# {'Low': 0.0, 'Normal': 0.0, 'High': 1.0, 'Very High': 0.0}

# %%
class custom_mf:
    def __init__(self, path):
        
        self.path = path
        
        self.xs = []
        self.bn_sev_con = [],
        self.bn_mod_con = []
        self.bn_mild_con = []
        self.no_con = []
        self.an_mild_con = []
        self.an_mod_con = []
        self.an_sev_con = []
        
        cats = ['Below normal - severe concern','Below normal - moderate concern','Below normal - mild concern','No concern','Above normal - mild concern','Above normal - moderate concern','Above normal - severe concern']
        
        ms = [self.bn_sev_con, self.bn_mod_con, self.bn_mild_con, self.no_con, self.an_mild_con, self.an_mod_con, self.an_sev_con]
        
        
        df = pd.read_csv(path)
        #"data/membership_function_plots/csv_data/heart_rate_membership_functions.csv")
        
        
        
        for i in df["Value"]:
            self.xs.append(i)
            
        for i in ms:
            for j in cats:
                ms[i] = df[j]
                j = j + 1

# %%
heart_rate = custom_mf(path = "data/membership_function_plots/csv_data/heart_rate_membership_functions.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 heart_rate = custom_mf(path = "data/membership_function_plots/csv_data/heart_rate_membership_functions.csv")
#
# Cell In[9], line 30, in custom_mf.__init__(self, path)
#      28 for i in ms:
#      29     for j in cats:
# ---> 30         ms[i] = df[j]
#      31         j = j + 1
#
# TypeError: list indices must be integers or slices, not tuple

# %%
print(heart_rate.ms[3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(heart_rate.ms[3])
#
# AttributeError: 'FuzzyVariable' object has no attribute 'ms'
